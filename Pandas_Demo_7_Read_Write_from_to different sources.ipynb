# %%
import pandas as pd

# %%
df = pd.read_csv('Data/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col ='Respondent')
schema_df = pd.read_csv('Data/stack-overflow-developer-survey-2019/survey_results_schema.csv', index_col = 'Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'Australia')
OZ_df = df.loc[filt]
# OZ_df.head()
OZ_df.to_csv('Data/OZ_df.csv')

# %%
# write to a tsv, tab seperated
OZ_df.to_csv('Data/OZ_df.tsv', sep='\t')

# %%
import xlwt
import openpyxl
import xlrd

# Write file to exel
OZ_df.to_excel('Data/OZ_df.xlsx')

# %%
test = pd.read_excel('Data/OZ_df.xlsx', index_col = 'Respondent')

# %%
test.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 17                             I am a developer by profession      Yes
# 67          I am not primarily a developer, but I write co...       No
# 131                            I am a developer by profession      Yes
# 153                            I am a developer by profession      Yes
# 177                            I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 17          Less than once a month but more than once per ...
# 67                                                      Never
# 131                                Once a month or more often
# 153                                Once a month or more often
# 177                                                     Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
# writing to a jSon file

OZ_df.to_json('Data/OZ_df.json', orient ='records', lines=True)

# %%
test = pd.read_json('Data/OZ_df.json', orient ='records', lines=True)
test.head()
# Out:
#                                           MainBranch Hobbyist  \
# 0                     I am a developer by profession      Yes
# 1  I am not primarily a developer, but I write co...       No
# 2                     I am a developer by profession      Yes
# 3                     I am a developer by profession      Yes
# 4                     I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0  Less than once a month but more than once per ...
# 1                                              Never
# 2                         Once a month or more often
# 3                         Once a month or more often
# 4                                              Never
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
#read and write from SQL database

# first we need to connect to the database in which we need some packages
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
OZ_df.to_sql('sample_table', engine)

# %%
# to update the table
OZ_df.to_sql('sample_table', engine, if_exists = 'replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index_col = 'Respondent')

# %%
#passin g query instead of a a table 

sql_df = pd.read_sql_quer('SELECT * FROM sample_table', engine, index_col = 'Respondent')

# %%
# reading frile from URL

posts_df = pd.read_json ('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
